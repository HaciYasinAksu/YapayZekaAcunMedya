# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.5/39.5 MB 837.5 kB/s eta 0:00:47
#     --------------------------------------- 0.8/39.5 MB 859.5 kB/s eta 0:00:46
#    - -------------------------------------- 1.0/39.5 MB 914.5 kB/s eta 0:00:43
#    - -------------------------------------- 1.3/39.5 MB 1.1 MB/s eta 0:00:34
#    -- ------------------------------------- 2.4/39.5 MB 1.7 MB/s eta 0:00:23
#    --- ------------------------------------ 3.9/39.5 MB 2.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 5.8/39.5 MB 3.2 MB/s eta 0:00:11
# ...

# %%
import cv2
image =cv2.imread("dataset/images/1.jpg")
image.shape,image.ndim
# Out:
# ((4608, 2592, 3), 3)

# %%
# !pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 932.9 kB/s eta 0:00:01
#    ------------------------------ --------- 0.8/1.0 MB 907.1 kB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 1.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/212.5 MB ? eta -:--:--
#    ---------------------------------------- 0.5/212.5 MB 4.2 MB/s eta 0:00:51
#    ---------------------------------------- 1.3/212.5 MB 3.0 MB/s eta 0:01:10
#    ---------------------------------------- 2.4/212.5 MB 3.7 MB/s eta 0:00:57
#     --------------------------------------- 4.5/212.5 MB 5.7 MB/s eta 0:00:37
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:00<00:00, 8.64MB/s]

# %% [markdown]
# yaml demek konfigürasyon dosyaları demektir.
# epochs => öğrenme kaç kez tekrarlanıcak
# imgsz => image ölçüsünü 640 a düşürdü.
# batch => çalışma başına kaç veri kullanılsın 2000/8 mesela

# %%
model.train(data="data.yaml" ,epochs = 1,imgsz=640 , batch = 8)
# Out:
# Ultralytics 8.3.131  Python-3.12.9 torch-2.7.0+cpu CPU (AMD Ryzen 5 3500X 6-Core Processor)
# ...
